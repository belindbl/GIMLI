# %%
import pandas as pd
import numpy as np

# %%
import os
import cv2
import open3d as o3d
import numpy as np

def project_points(points, K, T):
    """
    Projects 3D points (Nx3) from world (Lidar) coordinates into the 2D image plane.

    Args:
        points (np.ndarray): Nx3 array of 3D points.
        K (np.ndarray): 3x3 camera intrinsic matrix.
        T (np.ndarray): 4x4 extrinsic transformation (world-to-camera).

    Returns:
        proj_points (np.ndarray): Mx2 array of image coordinates.
        valid_mask (np.ndarray): Boolean mask for points with positive depth.
    """
    num_points = points.shape[0]
    # Convert to homogeneous coordinates.
    points_hom = np.hstack((points, np.ones((num_points, 1))))
    
    # Transform points into camera frame.
    points_cam_hom = (T @ points_hom.T).T
    points_cam = points_cam_hom[:, :3]
    
    # Keep only points with positive depth.
    valid_mask = points_cam[:, 2] > 0
    points_cam = points_cam[valid_mask]
    
    # Project onto image plane.
    proj = (K @ points_cam.T).T
    proj[:, 0] /= proj[:, 2]
    proj[:, 1] /= proj[:, 2]
    proj_points = proj[:, :2]
    return proj_points, valid_mask

def overlay_pcd_on_image(image, pcd_path, K, T, point_color=(0, 0, 255), point_radius=5):
    """
    Loads a PCD file, projects its points, and overlays them on the image.
    
    Args:
        image (np.ndarray): Input image.
        pcd_path (str): Path to the .pcd file.
        K (np.ndarray): Camera intrinsic matrix.
        T (np.ndarray): Extrinsic transformation (world-to-camera).
        point_color (tuple): BGR color for points (default red).
        point_radius (int): Circle radius for drawn points.
    
    Returns:
        image (np.ndarray): Image with overlaid points.
    """
    pcd = o3d.io.read_point_cloud(pcd_path)
    points = np.asarray(pcd.points)
    proj_points, _ = project_points(points, K, T)
    
    for pt in proj_points:
        x, y = int(round(pt[0])), int(round(pt[1]))
        # Draw point if within image bounds.
        if 0 <= x < image.shape[1] and 0 <= y < image.shape[0]:
            cv2.circle(image, (x, y), point_radius, point_color, thickness=-1)
    return image

def process_folders(img_folder, pcd_folder, shift, K, T, output_folder, target_size=(720, 480)):
    """
    For each image, finds the corresponding PCD (accounting for a frame shift), overlays the point cloud, and saves the result.
    
    Args:
        img_folder (str): Folder containing images.
        pcd_folder (str): Folder containing PCD files.
        shift (int): Frame shift: image_i corresponds to pcl_(i+shift).
        K (np.ndarray): Camera intrinsic matrix.
        T (np.ndarray): Extrinsic transformation matrix (world-to-camera).
        output_folder (str): Where to save output images.
        target_size (tuple): Resize images to (width, height).
    """
    # List image and PCD files (you may adjust the extensions if needed).
    img_files = sorted([f for f in os.listdir(img_folder) if f.lower().endswith(('.jpg','.png'))])
    pcd_files = sorted([f for f in os.listdir(pcd_folder) if f.lower().endswith('.pcd')])
    
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for i, img_file in enumerate(img_files):
        pcd_index = i + shift
        if pcd_index < 0 or pcd_index >= len(pcd_files):
            print(f"Skipping {img_file}: corresponding PCD index {pcd_index} is out of range.")
            continue
        
        img_path = os.path.join(img_folder, img_file)
        pcd_path = os.path.join(pcd_folder, pcd_files[pcd_index])
        
        image = cv2.imread(img_path)
        if image is None:
            print(f"Error reading image {img_path}. Skipping.")
            continue

        # Resize to expected dimensions.
        image = cv2.resize(image, target_size, interpolation=cv2.INTER_LINEAR)
        
        # Overlay Lidar points.
        overlaid_image = overlay_pcd_on_image(image, pcd_path, K, T)
        
        output_path = os.path.join(output_folder, img_file)
        cv2.imwrite(output_path, overlaid_image)
        print(f"Processed {img_file} with {pcd_files[pcd_index]} -> saved to {output_path}")

if __name__ == "__main__":
    # ----------------------------
    # Camera Intrinsic Parameters
    # ----------------------------
    # From your camera settings:
    #   ImageWidth = 720, ImageHeight = 480, FOV = 90°
    image_width, image_height = 720, 480
    fov_angle = 90
    # Compute focal length: f = (width/2) / tan(FOV/2)
    focal_length = image_width / (2 * np.tan(np.radians(fov_angle) / 2))  # should be 360
    cx, cy = image_width / 2, image_height / 2
    K = np.array([[focal_length, 0, cx],
                  [0, focal_length, cy],
                  [0, 0, 1]])
    print("Camera intrinsic matrix K:")
    print(K)
    
    # -----------------------------------------------------
    # Define the (working) transformation from world to camera.
    # This mimics the working script:
    #   1. Subtract the camera's world position.
    #   2. Rotate with R.
    # Where:
    #   Camera position (in world coordinates): [300.001, 0.0, 260.0]
    #   Rotation (world -> camera): 
    #       X_world -> Z_cam
    #       Y_world -> X_cam
    #       Z_world -> -Y_cam
    # -----------------------------------------------------
    t_cam = np.array([300.001, 0.0, 260.0])
    R_wc = np.array([
        [ 0, -1,  0],  # sim Y -> -X (camera)
        [ 0,  0,  -1],  # sim Z ->  Y  (camera)
        [ 1,  0,  0]   # sim X ->  Z  (camera)
    ])
    # Build the extrinsic matrix T = [R_wc, -R_wc * t_cam]
    T_world_to_cam = np.eye(4)
    T_world_to_cam[:3, :3] = R_wc
    T_world_to_cam[:3, 3] = -R_wc @ t_cam
    print("Extrinsic transformation matrix T (world-to-camera):")
    print(T_world_to_cam)
    
    # ----------------------------
    # Directories and Shift Setting
    # ----------------------------
    # (Update these paths as needed.)
    img_folder = "./imgs1"
    pcd_folder = "./pcl"
    output_folder = "./output"
    
    # Set the shift parameter.
    # For example, if shift = 57 then image_0 corresponds to pcl57.pcd.
    shift = -47
    
    process_folders(img_folder, pcd_folder, shift, K, T_world_to_cam, output_folder, target_size=(image_width, image_height))
# Out:
# Camera intrinsic matrix K:
# [[360.   0. 360.]
#  [  0. 360. 240.]
#  [  0.   0.   1.]]
# Extrinsic transformation matrix T (world-to-camera):
# [[   0.      -1.       0.       0.   ]
#  [   0.       0.      -1.     260.   ]
#  [   1.       0.       0.    -300.001]
#  [   0.       0.       0.       1.   ]]
# Skipping image_1.jpg: corresponding PCD index -47 is out of range.
# Skipping image_10.jpg: corresponding PCD index -46 is out of range.
# Skipping image_100.jpg: corresponding PCD index -45 is out of range.
# Skipping image_101.jpg: corresponding PCD index -44 is out of range.
# Skipping image_102.jpg: corresponding PCD index -43 is out of range.
# Skipping image_103.jpg: corresponding PCD index -42 is out of range.
# Skipping image_104.jpg: corresponding PCD index -41 is out of range.
# Skipping image_105.jpg: corresponding PCD index -40 is out of range.
# Skipping image_106.jpg: corresponding PCD index -39 is out of range.
# Skipping image_107.jpg: corresponding PCD index -38 is out of range.
# Skipping image_108.jpg: corresponding PCD index -37 is out of range.
# Skipping image_109.jpg: corresponding PCD index -36 is out of range.
# Skipping image_11.jpg: corresponding PCD index -35 is out of range.
# Skipping image_110.jpg: corresponding PCD index -34 is out of range.
# Skipping image_111.jpg: corresponding PCD index -33 is out of range.
# Skipping image_112.jpg: corresponding PCD index -32 is out of range.
# Skipping image_113.jpg: corresponding PCD index -31 is out of range.
# Skipping image_114.jpg: corresponding PCD index -30 is out of range.
# Skipping image_115.jpg: corresponding PCD index -29 is out of range.
# Skipping image_116.jpg: corresponding PCD index -28 is out of range.
# Skipping image_117.jpg: corresponding PCD index -27 is out of range.
# Skipping image_118.jpg: corresponding PCD index -26 is out of range.
# Skipping image_119.jpg: corresponding PCD index -25 is out of range.
# Skipping image_12.jpg: corresponding PCD index -24 is out of range.
# Skipping image_120.jpg: corresponding PCD index -23 is out of range.
# Skipping image_121.jpg: corresponding PCD index -22 is out of range.
# Skipping image_122.jpg: corresponding PCD index -21 is out of range.
# Skipping image_123.jpg: corresponding PCD index -20 is out of range.
# Skipping image_124.jpg: corresponding PCD index -19 is out of range.
# Skipping image_125.jpg: corresponding PCD index -18 is out of range.
# Skipping image_126.jpg: corresponding PCD index -17 is out of range.
# Skipping image_127.jpg: corresponding PCD index -16 is out of range.
# Skipping image_128.jpg: corresponding PCD index -15 is out of range.
# Skipping image_129.jpg: corresponding PCD index -14 is out of range.
# Skipping image_13.jpg: corresponding PCD index -13 is out of range.
# Skipping image_130.jpg: corresponding PCD index -12 is out of range.
# Skipping image_131.jpg: corresponding PCD index -11 is out of range.
# Skipping image_132.jpg: corresponding PCD index -10 is out of range.
# Skipping image_133.jpg: corresponding PCD index -9 is out of range.
# Skipping image_134.jpg: corresponding PCD index -8 is out of range.
# Skipping image_135.jpg: corresponding PCD index -7 is out of range.
# Skipping image_136.jpg: corresponding PCD index -6 is out of range.
# Skipping image_137.jpg: corresponding PCD index -5 is out of range.
# Skipping image_138.jpg: corresponding PCD index -4 is out of range.
# Skipping image_139.jpg: corresponding PCD index -3 is out of range.
# Skipping image_14.jpg: corresponding PCD index -2 is out of range.
# Skipping image_140.jpg: corresponding PCD index -1 is out of range.
# Processed image_141.jpg with pcl0.pcd -> saved to ./output/image_141.jpg
# Processed image_142.jpg with pcl1.pcd -> saved to ./output/image_142.jpg
# Processed image_143.jpg with pcl10.pcd -> saved to ./output/image_143.jpg
# Processed image_144.jpg with pcl100.pcd -> saved to ./output/image_144.jpg
# Processed image_145.jpg with pcl101.pcd -> saved to ./output/image_145.jpg
# Processed image_146.jpg with pcl102.pcd -> saved to ./output/image_146.jpg
# Processed image_147.jpg with pcl103.pcd -> saved to ./output/image_147.jpg
# Processed image_148.jpg with pcl104.pcd -> saved to ./output/image_148.jpg
# Processed image_149.jpg with pcl105.pcd -> saved to ./output/image_149.jpg
# Processed image_15.jpg with pcl106.pcd -> saved to ./output/image_15.jpg
# Processed image_150.jpg with pcl107.pcd -> saved to ./output/image_150.jpg
# Processed image_151.jpg with pcl108.pcd -> saved to ./output/image_151.jpg
# Processed image_152.jpg with pcl109.pcd -> saved to ./output/image_152.jpg
# Processed image_153.jpg with pcl11.pcd -> saved to ./output/image_153.jpg
# Processed image_154.jpg with pcl110.pcd -> saved to ./output/image_154.jpg
# Processed image_155.jpg with pcl111.pcd -> saved to ./output/image_155.jpg
# Processed image_156.jpg with pcl112.pcd -> saved to ./output/image_156.jpg
# Processed image_157.jpg with pcl113.pcd -> saved to ./output/image_157.jpg
# Processed image_16.jpg with pcl114.pcd -> saved to ./output/image_16.jpg
# Processed image_167.jpg with pcl115.pcd -> saved to ./output/image_167.jpg
# Processed image_168.jpg with pcl116.pcd -> saved to ./output/image_168.jpg
# Processed image_169.jpg with pcl117.pcd -> saved to ./output/image_169.jpg
# Processed image_17.jpg with pcl118.pcd -> saved to ./output/image_17.jpg
# Processed image_170.jpg with pcl119.pcd -> saved to ./output/image_170.jpg
# Processed image_171.jpg with pcl12.pcd -> saved to ./output/image_171.jpg
# Processed image_172.jpg with pcl120.pcd -> saved to ./output/image_172.jpg
# Processed image_173.jpg with pcl121.pcd -> saved to ./output/image_173.jpg
# Processed image_18.jpg with pcl122.pcd -> saved to ./output/image_18.jpg
# Processed image_183.jpg with pcl123.pcd -> saved to ./output/image_183.jpg
# Processed image_184.jpg with pcl124.pcd -> saved to ./output/image_184.jpg
# Processed image_185.jpg with pcl125.pcd -> saved to ./output/image_185.jpg
# Processed image_186.jpg with pcl126.pcd -> saved to ./output/image_186.jpg
# Processed image_187.jpg with pcl127.pcd -> saved to ./output/image_187.jpg
# Processed image_188.jpg with pcl128.pcd -> saved to ./output/image_188.jpg
# Processed image_189.jpg with pcl129.pcd -> saved to ./output/image_189.jpg
# Processed image_19.jpg with pcl13.pcd -> saved to ./output/image_19.jpg
# Processed image_199.jpg with pcl130.pcd -> saved to ./output/image_199.jpg
# Processed image_2.jpg with pcl131.pcd -> saved to ./output/image_2.jpg
# Processed image_20.jpg with pcl132.pcd -> saved to ./output/image_20.jpg
# Processed image_200.jpg with pcl133.pcd -> saved to ./output/image_200.jpg
# Processed image_201.jpg with pcl134.pcd -> saved to ./output/image_201.jpg
# Processed image_202.jpg with pcl135.pcd -> saved to ./output/image_202.jpg
# Processed image_203.jpg with pcl136.pcd -> saved to ./output/image_203.jpg
# Processed image_204.jpg with pcl137.pcd -> saved to ./output/image_204.jpg
# Processed image_205.jpg with pcl138.pcd -> saved to ./output/image_205.jpg
# Processed image_21.jpg with pcl139.pcd -> saved to ./output/image_21.jpg
# Processed image_215.jpg with pcl14.pcd -> saved to ./output/image_215.jpg
# Processed image_216.jpg with pcl140.pcd -> saved to ./output/image_216.jpg
# Processed image_217.jpg with pcl141.pcd -> saved to ./output/image_217.jpg
# Processed image_218.jpg with pcl142.pcd -> saved to ./output/image_218.jpg
# Processed image_219.jpg with pcl143.pcd -> saved to ./output/image_219.jpg
# Processed image_22.jpg with pcl144.pcd -> saved to ./output/image_22.jpg
# Processed image_220.jpg with pcl145.pcd -> saved to ./output/image_220.jpg
# Processed image_221.jpg with pcl146.pcd -> saved to ./output/image_221.jpg
# Processed image_23.jpg with pcl147.pcd -> saved to ./output/image_23.jpg
# Processed image_231.jpg with pcl148.pcd -> saved to ./output/image_231.jpg
# Processed image_232.jpg with pcl149.pcd -> saved to ./output/image_232.jpg
# Processed image_233.jpg with pcl15.pcd -> saved to ./output/image_233.jpg
# Processed image_234.jpg with pcl150.pcd -> saved to ./output/image_234.jpg
# Processed image_235.jpg with pcl151.pcd -> saved to ./output/image_235.jpg
# Processed image_236.jpg with pcl152.pcd -> saved to ./output/image_236.jpg
# Processed image_237.jpg with pcl153.pcd -> saved to ./output/image_237.jpg
# Processed image_24.jpg with pcl154.pcd -> saved to ./output/image_24.jpg
# Processed image_247.jpg with pcl155.pcd -> saved to ./output/image_247.jpg
# Processed image_248.jpg with pcl156.pcd -> saved to ./output/image_248.jpg
# Processed image_249.jpg with pcl157.pcd -> saved to ./output/image_249.jpg
# Processed image_25.jpg with pcl158.pcd -> saved to ./output/image_25.jpg
# Processed image_250.jpg with pcl159.pcd -> saved to ./output/image_250.jpg
# Processed image_251.jpg with pcl16.pcd -> saved to ./output/image_251.jpg
# Processed image_252.jpg with pcl160.pcd -> saved to ./output/image_252.jpg
# Processed image_253.jpg with pcl161.pcd -> saved to ./output/image_253.jpg
# Processed image_26.jpg with pcl162.pcd -> saved to ./output/image_26.jpg
# Processed image_263.jpg with pcl163.pcd -> saved to ./output/image_263.jpg
# Processed image_264.jpg with pcl164.pcd -> saved to ./output/image_264.jpg
# Processed image_265.jpg with pcl165.pcd -> saved to ./output/image_265.jpg
# Processed image_266.jpg with pcl166.pcd -> saved to ./output/image_266.jpg
# Processed image_267.jpg with pcl167.pcd -> saved to ./output/image_267.jpg
# Processed image_268.jpg with pcl168.pcd -> saved to ./output/image_268.jpg
# Processed image_269.jpg with pcl169.pcd -> saved to ./output/image_269.jpg
# Processed image_27.jpg with pcl17.pcd -> saved to ./output/image_27.jpg
# Processed image_279.jpg with pcl170.pcd -> saved to ./output/image_279.jpg
# Processed image_28.jpg with pcl171.pcd -> saved to ./output/image_28.jpg
# Processed image_280.jpg with pcl172.pcd -> saved to ./output/image_280.jpg
# Processed image_281.jpg with pcl173.pcd -> saved to ./output/image_281.jpg
# Processed image_282.jpg with pcl174.pcd -> saved to ./output/image_282.jpg
# Processed image_283.jpg with pcl175.pcd -> saved to ./output/image_283.jpg
# Processed image_284.jpg with pcl176.pcd -> saved to ./output/image_284.jpg
# Processed image_285.jpg with pcl177.pcd -> saved to ./output/image_285.jpg
# Processed image_29.jpg with pcl178.pcd -> saved to ./output/image_29.jpg
# Processed image_295.jpg with pcl179.pcd -> saved to ./output/image_295.jpg
# Processed image_296.jpg with pcl18.pcd -> saved to ./output/image_296.jpg
# Processed image_297.jpg with pcl180.pcd -> saved to ./output/image_297.jpg
# Processed image_298.jpg with pcl181.pcd -> saved to ./output/image_298.jpg
# Processed image_299.jpg with pcl182.pcd -> saved to ./output/image_299.jpg
# Processed image_3.jpg with pcl183.pcd -> saved to ./output/image_3.jpg
# Processed image_30.jpg with pcl184.pcd -> saved to ./output/image_30.jpg
# Processed image_300.jpg with pcl185.pcd -> saved to ./output/image_300.jpg
# Processed image_31.jpg with pcl186.pcd -> saved to ./output/image_31.jpg
# Processed image_32.jpg with pcl187.pcd -> saved to ./output/image_32.jpg
# Processed image_33.jpg with pcl188.pcd -> saved to ./output/image_33.jpg
# Processed image_34.jpg with pcl189.pcd -> saved to ./output/image_34.jpg
# Processed image_35.jpg with pcl19.pcd -> saved to ./output/image_35.jpg
# Processed image_36.jpg with pcl190.pcd -> saved to ./output/image_36.jpg
# Processed image_37.jpg with pcl191.pcd -> saved to ./output/image_37.jpg
# Processed image_38.jpg with pcl192.pcd -> saved to ./output/image_38.jpg
# Processed image_39.jpg with pcl193.pcd -> saved to ./output/image_39.jpg
# Processed image_4.jpg with pcl194.pcd -> saved to ./output/image_4.jpg
# Processed image_40.jpg with pcl195.pcd -> saved to ./output/image_40.jpg
# Processed image_41.jpg with pcl196.pcd -> saved to ./output/image_41.jpg
# Processed image_42.jpg with pcl197.pcd -> saved to ./output/image_42.jpg
# Processed image_43.jpg with pcl198.pcd -> saved to ./output/image_43.jpg
# Processed image_44.jpg with pcl199.pcd -> saved to ./output/image_44.jpg
# Processed image_45.jpg with pcl2.pcd -> saved to ./output/image_45.jpg
# Processed image_46.jpg with pcl20.pcd -> saved to ./output/image_46.jpg
# Processed image_47.jpg with pcl200.pcd -> saved to ./output/image_47.jpg
# Processed image_48.jpg with pcl201.pcd -> saved to ./output/image_48.jpg
# Processed image_49.jpg with pcl202.pcd -> saved to ./output/image_49.jpg
# Processed image_5.jpg with pcl203.pcd -> saved to ./output/image_5.jpg
# Processed image_50.jpg with pcl204.pcd -> saved to ./output/image_50.jpg
# Processed image_51.jpg with pcl205.pcd -> saved to ./output/image_51.jpg
# Processed image_52.jpg with pcl206.pcd -> saved to ./output/image_52.jpg
# Processed image_53.jpg with pcl207.pcd -> saved to ./output/image_53.jpg
# Processed image_54.jpg with pcl208.pcd -> saved to ./output/image_54.jpg
# Processed image_55.jpg with pcl209.pcd -> saved to ./output/image_55.jpg
# Processed image_56.jpg with pcl21.pcd -> saved to ./output/image_56.jpg
# Processed image_57.jpg with pcl210.pcd -> saved to ./output/image_57.jpg
# Processed image_58.jpg with pcl211.pcd -> saved to ./output/image_58.jpg
# Processed image_59.jpg with pcl212.pcd -> saved to ./output/image_59.jpg
# Processed image_6.jpg with pcl213.pcd -> saved to ./output/image_6.jpg
# Processed image_60.jpg with pcl214.pcd -> saved to ./output/image_60.jpg
# Processed image_61.jpg with pcl215.pcd -> saved to ./output/image_61.jpg
# Processed image_62.jpg with pcl216.pcd -> saved to ./output/image_62.jpg
# Processed image_63.jpg with pcl217.pcd -> saved to ./output/image_63.jpg
# Processed image_64.jpg with pcl218.pcd -> saved to ./output/image_64.jpg
# Processed image_65.jpg with pcl219.pcd -> saved to ./output/image_65.jpg
# Processed image_66.jpg with pcl22.pcd -> saved to ./output/image_66.jpg
# Processed image_67.jpg with pcl220.pcd -> saved to ./output/image_67.jpg
# Processed image_68.jpg with pcl221.pcd -> saved to ./output/image_68.jpg
# Processed image_69.jpg with pcl222.pcd -> saved to ./output/image_69.jpg
# Processed image_7.jpg with pcl223.pcd -> saved to ./output/image_7.jpg
# Processed image_70.jpg with pcl224.pcd -> saved to ./output/image_70.jpg
# Processed image_71.jpg with pcl225.pcd -> saved to ./output/image_71.jpg
# Processed image_72.jpg with pcl226.pcd -> saved to ./output/image_72.jpg
# Processed image_73.jpg with pcl227.pcd -> saved to ./output/image_73.jpg
# Processed image_74.jpg with pcl228.pcd -> saved to ./output/image_74.jpg
# Processed image_75.jpg with pcl229.pcd -> saved to ./output/image_75.jpg
# Processed image_76.jpg with pcl23.pcd -> saved to ./output/image_76.jpg
# Processed image_77.jpg with pcl230.pcd -> saved to ./output/image_77.jpg
# Processed image_78.jpg with pcl231.pcd -> saved to ./output/image_78.jpg
# Processed image_79.jpg with pcl232.pcd -> saved to ./output/image_79.jpg
# Processed image_8.jpg with pcl233.pcd -> saved to ./output/image_8.jpg
# Processed image_80.jpg with pcl234.pcd -> saved to ./output/image_80.jpg
# Processed image_81.jpg with pcl235.pcd -> saved to ./output/image_81.jpg
# Processed image_82.jpg with pcl236.pcd -> saved to ./output/image_82.jpg
# Processed image_83.jpg with pcl237.pcd -> saved to ./output/image_83.jpg
# Processed image_84.jpg with pcl238.pcd -> saved to ./output/image_84.jpg
# Processed image_85.jpg with pcl239.pcd -> saved to ./output/image_85.jpg
# Processed image_86.jpg with pcl24.pcd -> saved to ./output/image_86.jpg
# Processed image_87.jpg with pcl240.pcd -> saved to ./output/image_87.jpg
# Processed image_88.jpg with pcl241.pcd -> saved to ./output/image_88.jpg
# Processed image_89.jpg with pcl242.pcd -> saved to ./output/image_89.jpg
# Processed image_9.jpg with pcl243.pcd -> saved to ./output/image_9.jpg
# Processed image_90.jpg with pcl244.pcd -> saved to ./output/image_90.jpg
# Processed image_91.jpg with pcl245.pcd -> saved to ./output/image_91.jpg
# Processed image_92.jpg with pcl246.pcd -> saved to ./output/image_92.jpg
# Processed image_93.jpg with pcl247.pcd -> saved to ./output/image_93.jpg
# Processed image_94.jpg with pcl248.pcd -> saved to ./output/image_94.jpg
# Processed image_95.jpg with pcl249.pcd -> saved to ./output/image_95.jpg
# Processed image_96.jpg with pcl25.pcd -> saved to ./output/image_96.jpg
# Processed image_97.jpg with pcl250.pcd -> saved to ./output/image_97.jpg
# Processed image_98.jpg with pcl251.pcd -> saved to ./output/image_98.jpg
# Processed image_99.jpg with pcl252.pcd -> saved to ./output/image_99.jpg
