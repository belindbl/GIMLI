# %% [markdown]
# # Script for merging Camera and Lidar Data

# %%
import numpy as np
import open3d as o3d
import cv2
import os
import glob

# Directories
camera_dir = "/Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw"
lidar_dir = "/Users/amosweckstrom/Desktop/ÅBOAT/LidarData"
output_dir = os.path.join(camera_dir, "lidar_overlay")

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Camera intrinsic parameters
image_width, image_height = 720, 480
fov_angle = 90
focal_length = image_width / (2 * np.tan(np.radians(fov_angle) / 2))
cx, cy = image_width / 2, image_height / 2
K = np.array([[focal_length, 0, cx],
              [0, focal_length, cy],
              [0, 0, 1]])

# Camera translation in world frame (from the provided config)
cam_tx, cam_ty, cam_tz = 300.001, 0.0, 260.0

# Rotation from world frame to camera frame:
# World -> Camera:
# X_world -> Z_cam
# Y_world -> X_cam
# Z_world -> -Y_cam
R = np.array([
    [0,  1,  0],
    [0,  0, -1],
    [1,  0,  0]
])

# Gather image and Lidar files
image_files = glob.glob(os.path.join(camera_dir, "processed_image_*.png"))
image_files.sort()

lidar_files = glob.glob(os.path.join(lidar_dir, "pcl*.pcd"))
lidar_files.sort()

# Parse the numeric index from filenames.
# Images are like processed_image_0000.png -> index 0
# Lidar are like pcl0.pcd -> index 0

def extract_image_index(filename):
    # Extract from processed_image_XXXX.png
    # Example: processed_image_0000.png -> index 0
    base = os.path.basename(filename)
    name_no_ext, _ = os.path.splitext(base)
    # name_no_ext = "processed_image_0000"
    parts = name_no_ext.split("_")
    if len(parts) < 3:
        return None
    idx_str = parts[-1]
    if idx_str.isdigit():
        return int(idx_str)
    return None

def extract_lidar_index(filename):
    # Extract from pclX.pcd
    # Example: pcl0.pcd -> index 0
    base = os.path.basename(filename)
    name_no_ext, _ = os.path.splitext(base)
    # name_no_ext = "pcl0"
    if name_no_ext.startswith("pcl"):
        idx_str = name_no_ext[3:]
        if idx_str.isdigit():
            return int(idx_str)
    return None

# Create a map from index to lidar file
lidar_index_map = {}
for lf in lidar_files:
    li = extract_lidar_index(lf)
    if li is not None:
        lidar_index_map[li] = lf

# Process each image, find corresponding Lidar
for img_path in image_files:
    frame_index = extract_image_index(img_path)
    if frame_index is None:
        print(f"Skipping {img_path}, cannot parse frame index.")
        continue

    if frame_index not in lidar_index_map:
        print(f"No matching Lidar file for image {img_path} (index: {frame_index}). Skipping.")
        continue

    lidar_file = lidar_index_map[frame_index]

    # Load camera image
    camera_img = cv2.imread(img_path, cv2.IMREAD_COLOR)
    if camera_img is None:
        print(f"Cannot load image at {img_path}, skipping.")
        continue

    camera_img = cv2.resize(camera_img, (image_width, image_height), interpolation=cv2.INTER_LINEAR)

    # Load LiDAR point cloud
    pcd = o3d.io.read_point_cloud(lidar_file)
    points = np.asarray(pcd.points)

    # Transform points into camera frame
    points_translated = points - np.array([cam_tx, cam_ty, cam_tz])
    points_cam = points_translated @ R.T

    # Project and overlay LiDAR points
    circle_radius = 5    # Increase point size
    circle_thickness = -1
    point_color = (0, 0, 255) # Red

    for Xc, Yc, Zc in points_cam:
        # Only consider points in front of camera
        if Zc <= 0:
            continue
        uv = K @ np.array([Xc, Yc, Zc])
        u, v = uv[0] / uv[2], uv[1] / uv[2]

        u_int, v_int = int(round(u)), int(round(v))
        if 0 <= u_int < image_width and 0 <= v_int < image_height:
            cv2.circle(camera_img, (u_int, v_int), radius=circle_radius, color=point_color, thickness=circle_thickness)

    # Save the overlayed image
    output_path = os.path.join(output_dir, f"overlay_{frame_index}.png")
    cv2.imwrite(output_path, camera_img)
    print(f"Saved overlayed image: {output_path}")
# Out:
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_0.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_1.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_2.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_3.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_4.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_5.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_6.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_7.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_8.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_9.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_10.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_11.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_12.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_13.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_14.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_15.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_16.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_17.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_18.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_19.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_20.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_21.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_22.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_23.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_24.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_25.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_26.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_27.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_28.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_29.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_30.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_31.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_32.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_33.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_34.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_35.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_36.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_37.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_38.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_39.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_40.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_41.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_42.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_43.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_44.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_45.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_46.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_47.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_48.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_49.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_50.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_51.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_52.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_53.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_54.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_55.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_56.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_57.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_58.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_59.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_60.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_61.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_62.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_63.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_64.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_65.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_66.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_67.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_68.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_69.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_70.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_71.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_72.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_73.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_74.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_75.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_76.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_77.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_78.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_79.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_80.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_81.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_82.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_83.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_84.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_85.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_86.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_87.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_88.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_89.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_90.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_91.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_92.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_93.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_94.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_95.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_96.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_97.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_98.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_99.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_100.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_101.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_102.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_103.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_104.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_105.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_106.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_107.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_108.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_109.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_110.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_111.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_112.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_113.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_114.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_115.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_116.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_117.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_118.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_119.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_120.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_121.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_122.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_123.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_124.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_125.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_126.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_127.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_128.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_129.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_130.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_131.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_132.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_133.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_134.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_135.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_136.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_137.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_138.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_139.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_140.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_141.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_142.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_143.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_144.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_145.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_146.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_147.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_148.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_149.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_150.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_151.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_152.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_153.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_154.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_155.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_156.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_157.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_158.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_159.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_160.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_161.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_162.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_163.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_164.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_165.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_166.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_167.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_168.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_169.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_170.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_171.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_172.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_173.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_174.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_175.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_176.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_177.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_178.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_179.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_180.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_181.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_182.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_183.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_184.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_185.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_186.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_187.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_188.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_189.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_190.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_191.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_192.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_193.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_194.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_195.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_196.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_197.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_198.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_199.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_200.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_201.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_202.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_203.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_204.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_205.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_206.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_207.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_208.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_209.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_210.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_211.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_212.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_213.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_214.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_215.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_216.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_217.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_218.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_219.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_220.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_221.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_222.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_223.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_224.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_225.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_226.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_227.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_228.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_229.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_230.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_231.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_232.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_233.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_234.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_235.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_236.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_237.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_238.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_239.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_240.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_241.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_242.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_243.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_244.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_245.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_246.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_247.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_248.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_249.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_250.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_251.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_252.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_253.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_254.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_255.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_256.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_257.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_258.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_259.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_260.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_261.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_262.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_263.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_264.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_265.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_266.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_267.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_268.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_269.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_270.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_271.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_272.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_273.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_274.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_275.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_276.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_277.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_278.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_279.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_280.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_281.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_282.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_283.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_284.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_285.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_286.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_287.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_288.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_289.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_290.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_291.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_292.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_293.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_294.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_295.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_296.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_297.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_298.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_299.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_300.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_301.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_302.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_303.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_304.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_305.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_306.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_307.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_308.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_309.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_310.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_311.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_312.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_313.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_314.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_315.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_316.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_317.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_318.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_319.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_320.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_321.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_322.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_323.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_324.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_325.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_326.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_327.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_328.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_329.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_330.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_331.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_332.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_333.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_334.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_335.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_336.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_337.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_338.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_339.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_340.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_341.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_342.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_343.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_344.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_345.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_346.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_347.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_348.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_349.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_350.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_351.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_352.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_353.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_354.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_355.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_356.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_357.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_358.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_359.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_360.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_361.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_362.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_363.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_364.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_365.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_366.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_367.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_368.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_369.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_370.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_371.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_372.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_373.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_374.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_375.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_376.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_377.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_378.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_379.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_380.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_381.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_382.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_383.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_384.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_385.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_386.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_387.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_388.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_389.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_390.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_391.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_392.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_393.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_394.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_395.png
# Saved overlayed image: /Users/amosweckstrom/Desktop/ÅBOAT/CameraData/captured_images_raw/lidar_overlay/overlay_396.png
